# %% [markdown]
#  Q1) In the below elements which of them are values or an expression? eg:- values can be
# integer or string and expressions will be mathematical operators.
# *
# 'hello'
# -87.8
# -
# /
# +
# 6
#
#
# ANSWER: values are 'hello' -87.8 6 , where as expressions are *  - +
#
#
#
#  Q2) What is the difference between string and variable?
#
#  ANSWER: variable is that where we store information where as string is a type of inormation stored in a variable.
#  ex: x="nihali" where x is variable storing string information in double code as "nihali"
#
#
#  Q3)Describe three different data types.
#
#  ANSWER:data types are-
#          1)string: used for alphanumeri character eg: nihali0327
#          2)integer:used for whole numbers eg: 25,500
#          3)float  :used for number with decimal point eg: 25.500
#          4)boolean:used for representing ligical values eg: True , False
#
#
#  Q4) What is an expression made up of? What do all expressions do?
#
#  ANSWER: An expression is a combination of operators and operands that is used for producing some other result.
#  eg:operators are +-/* etc and operands are constant or variables functions all .
#
#
#
#  Q5). This assignment statements, like spam = 10. What is the difference between an expression and a statement?
#
#  ANSWER: spam =10 is an expression
#          # spam = 10 is a statement or say comment
#
#
#   Q6)6. After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1
# ANSWER: baccon =23
#
#
# Q7)7. What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3
#  ANSWER: 'spamspamspam'
#
#
#
#  Q8)Why is eggs a valid variable name while 100 is invalid?
#  ANSWER: eggs is a valid variable because it stores temporary information and can be changed time to time. where as 100 is a constant integer which is fixed number and cannot be changed.
#
#
#  Q9)What three functions can be used to get the integer, floating-point number, or string version of a value?
#  ANSWER: integer-int()
#          float point- float()
#          string-  str()
#
#
#
#   Q10)Why does this expression cause an error? How can you fix it?
#  'I have eaten ' + 99 + ' burritos.'
#
#  ANSWER: because 99 is not taken in singlecode so it is not working like a string without singlecode.rest are string data types so 99 has to be also string datatype then only it will get added up altogetr to give output as 'I have eaten99burritos'  .
